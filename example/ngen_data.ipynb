# %%
import numpy as np
import pandas as pd
import xarray as xr

forc_path = '/projects/mhpi/leoglonz/ciroh-ua/dhbv2_mts/ngen_resources/data/forcing/cat-67_2015-12-01 00_00_00_2015-12-30 23_00_00.csv'


x = pd.read_csv(forc_path)

# %%
x['PET_hargreaves'].mean()

# %%
hourly_x_path = (
    '/gpfs/yxs275/data/hourly/CAMELS_HF/forcing/forcing_1990_2018_gauges_00000_00499.nc'
)
zTest_full_time = pd.date_range('2004-10-01 00:00:00', '2018-10-01 00:00:00', freq='h')[
    :-1
]

hourly_x = xr.open_dataset(hourly_x_path)

# %%
f = hourly_x['PET'][:]
f.mean()

# %%
f.as_numpy()[:10, 1]
